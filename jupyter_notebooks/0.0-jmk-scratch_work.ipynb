# %% [markdown]
# # Import Libraries

# %%
# Auto reloads src modules.
# %load_ext autoreload
# %autoreload 2

# Import custom libraries.
import os
import sys
from pathlib import Path, PurePath

if Path.cwd().parts[-1] != "crnn-pytorch":
    proj_root = str(Path.cwd().parents[0])
if proj_root not in sys.path:
    sys.path.append(proj_root)

# Changes the working directory from a jupyter_notebook to the project directory.
if Path.cwd().parts[-1] == "jupyter_notebooks":
    os.chdir(proj_root)

from src.dataset import extract_jpg_meta, WbsinImageDataset
from torchvision import transforms
import torch
import matplotlib.pyplot as plt
import pandas as pd
import xml.etree.ElementTree as ET
from PIL import Image
import altair as alt
alt.data_transformers.disable_max_rows()
from tqdm.auto import tqdm
tqdm.pandas()
from PIL import Image
import altair as alt
alt.data_transformers.disable_max_rows()
from tqdm.auto import tqdm
import numpy as np
tqdm.pandas()
import cv2
from PIL import Image as im
from scipy.ndimage import interpolation as inter

# %% [markdown]
# # Metadata preprocessing

# %%
interim_path = Path.cwd() / "data" / "interim"

wbsin_meta_df = pd.read_csv(interim_path / "wbsin_meta.csv")
wbsin_meta_df["xml_path"] = wbsin_meta_df["file_path"].apply(
    lambda x: x.replace("jpg", "xml")
)

# %%
wbsin_meta_df["bnd_box"] = wbsin_meta_df["xml_path"].apply(lambda x: extract_bnd_box(x))

# %%
def crop_and_save(file_path, label, xmin, xmax, ymin, ymax, save_dir):
    og_img = Image.open(file_path)
    cropped_img = og_img.crop((xmin, ymin, xmax, ymax))

    cropped_img.save(save_dir / f"{label}.jpg")
    return save_dir / f"{label}.jpg"
# Out:
# 100%|██████████| 6059/6059 [03:14<00:00, 31.22it/s]

# %%
wbsin_meta_df["crop_height"] = wbsin_meta_df.progress_apply(
    lambda row: row["bnd_box"]["ymax"] - row["bnd_box"]["ymin"], axis=1
)
wbsin_meta_df["crop_width"] = wbsin_meta_df.progress_apply(
    lambda row: row["bnd_box"]["xmax"] - row["bnd_box"]["xmin"], axis=1
)

wbsin_meta_df["crop_ratio"] = wbsin_meta_df["crop_width"] / wbsin_meta_df["crop_height"]
# Out:
# 100%|██████████| 6059/6059 [00:00<00:00, 49932.58it/s]
# 100%|██████████| 6059/6059 [00:00<00:00, 49650.65it/s]

# %%
wbsin_meta_df.to_csv(Path.cwd() / "data" / "interim" / "cropped_wbsin_meta.csv", index=False)

# %%
def preprocess_cropped_image(cropped_image_path, label, save_dir):
    def find_score(arr, angle):
        data = inter.rotate(arr, angle, reshape=False, order=0)
        hist = np.sum(data, axis=1)
        score = np.sum((hist[1:] - hist[:-1]) ** 2)
        return hist, score
        

    # Reads original image
    img = cv2.imread(cropped_image_path,0)

    # Applies adaptive threshold image.
    img = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY, blockSize=3,C=3)

    # Contour dilates image.
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 1))
    img = cv2.dilate(img, kernel)

    # Blurs.
    blur = cv2.GaussianBlur(img,(3,3),0)
    img = cv2.threshold(blur, 100, 255, cv2.THRESH_BINARY)[1]

    # Thins image.
    kernel = np.ones((3,3),np.uint8)
    img = cv2.erode(img,kernel,iterations = 2)

    # Fixes skew.
    delta = .05
    limit = 4.0
    angles = np.arange(-.5, limit+delta, delta)
    scores = []
    for angle in angles:
        hist, score = find_score(img, angle)
        scores.append(score)
    best_score = max(scores)
    best_angle = angles[scores.index(best_score)]
    best_angle = best_angle.round(2)


    img = im.fromarray(img)
    img = img.rotate(best_angle, expand=1, fillcolor="white")
    img.save(save_dir / f"{label}.jpg")
    return save_dir / f"{label}.jpg"

wbsin_meta_df["proc_path"] = wbsin_meta_df.progress_apply(
    lambda row: preprocess_cropped_image(
        str(row["crop_path"]),
        row["label"],
        Path.cwd() / "data" / "processed" / "wbsin_images",
    ),
    axis=1,
)
# Out:
# 100%|██████████| 6059/6059 [1:04:47<00:00,  1.56it/s]

# %%
wbsin_meta_df.to_csv(Path.cwd() / "data" / "processed" / "processed_wbsin_meta.csv", index=False)

# %%
wbsin_meta_df
# Out:
#                                               file_path              label  \
# 0     C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328168
# 1     C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328199
# 2     C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328235
# 3     C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328266
# 4     C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328350
# ...                                                 ...                ...
# 6054  C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328039
# 6055  C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328042
# 6056  C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA24AD6LE328056
# 6057  C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA241AALE328554
# 6058  C:\Users\KMA62139\OneDrive - Kia\Documents - B...  3KPA241A0ME327203
#
#       width  height                                           xml_path  \
# 0      1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 1      1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 2      1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 3      1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 4      1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# ...     ...     ...                                                ...
# 6054   1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6055   1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6056   1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6057   1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6058   1280     720  C:\Users\KMA62139\OneDrive - Kia\Documents - B...
#
#                                                 bnd_box  \
# 0     {'xmin': 85.0, 'xmax': 967.0, 'ymin': 188.0, '...
# 1     {'xmin': 84.0, 'xmax': 968.0, 'ymin': 172.0, '...
# 2     {'xmin': 76.0, 'xmax': 960.0, 'ymin': 150.0, '...
# 3     {'xmin': 52.0, 'xmax': 1058.0, 'ymin': 231.0, ...
# 4     {'xmin': 84.0, 'xmax': 966.0, 'ymin': 160.0, '...
# ...                                                 ...
# 6054  {'xmin': 85.0, 'xmax': 969.0, 'ymin': 146.0, '...
# 6055  {'xmin': 44.0, 'xmax': 1053.0, 'ymin': 234.0, ...
# 6056  {'xmin': 116.0, 'xmax': 998.0, 'ymin': 182.0, ...
# 6057  {'xmin': 92.0, 'xmax': 976.0, 'ymin': 160.0, '...
# 6058  {'xmin': 66.0, 'xmax': 948.0, 'ymin': 144.0, '...
#
#                                               crop_path  crop_height  \
# 0     c:\Users\KMA62139\OneDrive - Kia\Documents - B...         82.0
# 1     c:\Users\KMA62139\OneDrive - Kia\Documents - B...         82.0
# 2     c:\Users\KMA62139\OneDrive - Kia\Documents - B...         84.0
# 3     c:\Users\KMA62139\OneDrive - Kia\Documents - B...        134.0
# 4     c:\Users\KMA62139\OneDrive - Kia\Documents - B...         84.0
# ...                                                 ...          ...
# 6054  c:\Users\KMA62139\OneDrive - Kia\Documents - B...         85.0
# 6055  c:\Users\KMA62139\OneDrive - Kia\Documents - B...        132.0
# 6056  c:\Users\KMA62139\OneDrive - Kia\Documents - B...         85.0
# 6057  c:\Users\KMA62139\OneDrive - Kia\Documents - B...         85.0
# 6058  c:\Users\KMA62139\OneDrive - Kia\Documents - B...         84.0
#
#       crop_width  crop_ratio  \
# 0          882.0   10.756098
# 1          884.0   10.780488
# 2          884.0   10.523810
# 3         1006.0    7.507463
# 4          882.0   10.500000
# ...          ...         ...
# 6054       884.0   10.400000
# 6055      1009.0    7.643939
# 6056       882.0   10.376471
# 6057       884.0   10.400000
# 6058       882.0   10.500000
#
#                                               proc_path
# 0     c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 1     c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 2     c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 3     c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 4     c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# ...                                                 ...
# 6054  c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6055  c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6056  c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6057  c:\Users\KMA62139\OneDrive - Kia\Documents - B...
# 6058  c:\Users\KMA62139\OneDrive - Kia\Documents - B...
#
# [6059 rows x 11 columns]
